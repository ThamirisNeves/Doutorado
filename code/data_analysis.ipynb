# %%
import mne 
import pandas as pd
import numpy as np
import pathlib

# %%
raw = mne.io.read_raw_bdf(r"C:\Users\Marcio Neves\Documents\Doutorado\dados\Motor_imagery\EDVALDO CAVALCANTE DE QUEIROZ.bdf")
# Out:
# Extracting BDF parameters from C:\Users\Marcio Neves\Documents\Doutorado\dados\Motor_imagery\EDVALDO CAVALCANTE DE QUEIROZ.bdf...
# Setting channel info structure...
# Creating raw.info structure...

# %%
print(raw.ch_names)
# Out:
# ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P8', 'P6', 'P10', 'PO8', 'PO4', 'O2', 'EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG5', 'EXG6', 'EXG7', 'EXG8', 'Status']

# %%
raw_eeg = raw.copy().pick_types(eeg=True)
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <RawBDF | EDVALDO CAVALCANTE DE QUEIROZ.bdf, 64 x 936960 (915.0 s), ~64 KiB, data not loaded>

# %%
raw_eeg.drop_channels([f"EXG{i}" for i in range(1, 9) if f"EXG{i}" in raw_eeg.ch_names])
# Out:
# <RawBDF | EDVALDO CAVALCANTE DE QUEIROZ.bdf, 64 x 936960 (915.0 s), ~64 KiB, data not loaded>

# %%
data = raw_eeg.get_data()

# %%
data.shape
# Out:
# (64, 936960)

# %%
pd.DataFrame(data.T)
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.009586 -0.012847 -0.022691  0.007423  0.000619 -0.026064 -0.011939
# 1      -0.009577 -0.012832 -0.022677  0.007437  0.000632 -0.026051 -0.011926
# 2      -0.009648 -0.012894 -0.022738  0.007375  0.000570 -0.026113 -0.011987
# 3      -0.009663 -0.012904 -0.022751  0.007366  0.000560 -0.026124 -0.011997
# 4      -0.009588 -0.012826 -0.022678  0.007444  0.000636 -0.026049 -0.011921
# ...          ...       ...       ...       ...       ...       ...       ...
# 936955 -0.009889 -0.011810 -0.019146  0.004534 -0.000975 -0.024507 -0.010392
# 936956 -0.009857 -0.011782 -0.019118  0.004562 -0.000946 -0.024476 -0.010364
# 936957 -0.009874 -0.011800 -0.019140  0.004542 -0.000967 -0.024497 -0.010382
# 936958 -0.009885 -0.011810 -0.019152  0.004529 -0.000980 -0.024509 -0.010392
# 936959 -0.009882 -0.011805 -0.019148  0.004531 -0.000977 -0.024505 -0.010387
#
#               7         8         9   ...        54        55        56  \
# 0      -0.013156 -0.007211  0.002302  ...  0.008613  0.001195  0.003818
# 1      -0.013143 -0.007199  0.002314  ...  0.008628  0.001210  0.003832
# 2      -0.013204 -0.007262  0.002252  ...  0.008570  0.001151  0.003775
# 3      -0.013212 -0.007270  0.002242  ...  0.008563  0.001145  0.003772
# 4      -0.013136 -0.007192  0.002317  ...  0.008640  0.001221  0.003846
# ...          ...       ...       ...  ...       ...       ...       ...
# 936955 -0.011555 -0.007938 -0.001208  ...  0.013030 -0.002049 -0.001687
# 936956 -0.011528 -0.007910 -0.001179  ...  0.013059 -0.002022 -0.001661
# 936957 -0.011547 -0.007929 -0.001200  ...  0.013039 -0.002043 -0.001682
# 936958 -0.011559 -0.007939 -0.001212  ...  0.013026 -0.002054 -0.001695
# 936959 -0.011554 -0.007936 -0.001208  ...  0.013027 -0.002053 -0.001695
#
#               57        58        59        60        61        62        63
# 0       0.002175  0.000767  0.006188 -0.005613  0.008095  0.005661  0.000701
# 1       0.002191  0.000784  0.006207 -0.005591  0.008121  0.005677  0.000722
# 2       0.002135  0.000728  0.006149 -0.005648  0.008068  0.005622  0.000666
# 3       0.002129  0.000720  0.006140 -0.005660  0.008060  0.005617  0.000658
# 4       0.002204  0.000794  0.006214 -0.005586  0.008130  0.005689  0.000731
# ...          ...       ...       ...       ...       ...       ...       ...
# 936955  0.002393  0.000315  0.003430 -0.005838  0.005912  0.003316  0.001777
# 936956  0.002419  0.000341  0.003457 -0.005810  0.005941  0.003341  0.001805
# 936957  0.002400  0.000320  0.003436 -0.005825  0.005921  0.003320  0.001785
# 936958  0.002386  0.000306  0.003422 -0.005834  0.005905  0.003306  0.001768
# 936959  0.002387  0.000307  0.003424 -0.005830  0.005904  0.003306  0.001766
#
# [936960 rows x 64 columns]
